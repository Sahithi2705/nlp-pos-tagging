# %%
# !pip install nltk

import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

from nltk.tokenize import word_tokenize
from nltk import pos_tag
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.

# %%
text = """
Natural Language Processing enables computers to understand human language.
Students learn Python for machine learning and artificial intelligence.
"""

print(text)
# Out:
# Natural Language Processing enables computers to understand human language.
# Students learn Python for machine learning and artificial intelligence.

# %%
tokens = word_tokenize(text)

print(tokens)
# Out:
# ['Natural', 'Language', 'Processing', 'enables', 'computers', 'to', 'understand', 'human', 'language', '.', 'Students', 'learn', 'Python', 'for', 'machine', 'learning', 'and', 'artificial', 'intelligence', '.']

# %%
tagged_words = pos_tag(tokens)

print("Part-of-Speech Tags:\n")

for word, tag in tagged_words:
    print(f"{word:<15} {tag}")
# Out:
# Part-of-Speech Tags:
#
# Natural         JJ
# Language        NNP
# Processing      NNP
# enables         VBZ
# computers       NNS
# to              TO
# understand      VB
# human           JJ
# language        NN
# .               .
# Students        NNS
# learn           VBP
# Python          NNP
# for             IN
# machine         NN
# learning        NN
# and             CC
# artificial      JJ
# intelligence    NN
# .               .

# %%
import pandas as pd

df = pd.DataFrame(tagged_words, columns=["Word", "POS Tag"])

df
# Out:
#             Word POS Tag
# 0        Natural      JJ
# 1       Language     NNP
# 2     Processing     NNP
# 3        enables     VBZ
# 4      computers     NNS
# 5             to      TO
# 6     understand      VB
# 7          human      JJ
# 8       language      NN
# 9              .       .
# 10      Students     NNS
# 11         learn     VBP
# 12        Python     NNP
# 13           for      IN
# 14       machine      NN
# 15      learning      NN
# 16           and      CC
# 17    artificial      JJ
# 18  intelligence      NN
# 19             .       .

# %%
sentence = input("Enter a sentence:\n")

tokens = word_tokenize(sentence)

tagged = pos_tag(tokens)

for word, tag in tagged:
    print(word, ":", tag)
# Out:
# Enter a sentence:
#  instantiating every entity, attribute, and relationship defined in the design into a live, structured system using SQL Data Definition Language
# instantiating : VBG
# every : DT
# entity : NN
# , : ,
# attribute : NN
# , : ,
# and : CC
# relationship : NN
# defined : VBN
# in : IN
# the : DT
# design : NN
# into : IN
# a : DT
# live : JJ
# , : ,
# structured : JJ
# system : NN
# using : VBG
# SQL : NNP
# Data : NNP
# Definition : NNP
# Language : NNP
